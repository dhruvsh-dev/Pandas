# %% [markdown]
# ## Creating  Series

# %%
import numpy as np

# %%
import pandas as pd

# %%
labels=['a','b','c']
mylist= [10,20,30]
arr= np.array(mylist)
dic={
    1:10,2:20,3:30
}

# %%
pd.Series(mylist)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(mylist,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(dic)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
